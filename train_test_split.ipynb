# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("data/500hits.csv", encoding="latin-1")
df.sample(n=10)
# Out:
#               PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 20        Wade Boggs   18  2440   9180  1513  3010  578   61  118  1014  1412
# 2       Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 300        Fred Lynn   17  1969   6925  1063  1960  388   43  306  1111   857
# 33           Mel Ott   22  2730   9456  1859  2876  488   72  511  1860  1708
# 116      Gary Carter   19  2296   7971  1025  2092  371   31  324  1225   848
# 330      Brian Giles   15  1847   6527  1121  1897  411   55  287  1078  1183
# 41      Andre Dawson   21  2627   9927  1373  2774  503   98  438  1591   589
# 208    Darrell Evans   21  2687   8973  1344  2223  329   36  414  1354  1605
# 211  Willie Randolph   18  2202   8018  1239  2210  316   65   54   687  1243
# 153        Al Oliver   18  2368   9049  1189  2743  529   77  219  1326   535
#
#        SO   SB   CS     BA  HOF
# 20    745   24   35  0.328    1
# 2     220  432  129  0.345    1
# 300  1116   72   54  0.283    0
# 33    896   89    0  0.304    1
# 116   997   39   42  0.262    1
# 330   835  109   45  0.291    0
# 41   1509  314  110  0.279    1
# 208  1410   98   68  0.248    0
# 211   675  271   94  0.276    0
# 153   756   84   64  0.303    0

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.drop(columns=["PLAYER"]).corr().round(2), annot=True, cmap="icefire")
plt.show()

# %%
X = df.drop(columns=["PLAYER", "HOF"])
y = df["HOF"]

# %%
X.sample(n=5)
# Out:
#      YRS     G    AB     R     H   2B  3B   HR   RBI    BB    SO   SB   CS  \
# 383   16  2019  7060   982  1790  289  38  242  1039  1031   923   75   46
# 41    21  2627  9927  1373  2774  503  98  438  1591   589  1509  314  110
# 67    21  2456  8680  1074  2472  483  47  248  1389   855   694   21   33
# 280   16  2033  7147  1083  2011  319  51  234   978   940  1125  183   74
# 379   17  1768  6879   891  1797  228  70   29     0   364   214  268    0
#
#         BA
# 383  0.254
# 41   0.279
# 67   0.285
# 280  0.281
# 379  0.261

# %%
y.sample(n=5)
# Out:
# 212    0
# 167    0
# 207    0
# 331    0
# 433    0
# Name: HOF, dtype: int64

# %%
print(X.shape)
print(y.shape)
# Out:
# (465, 14)
# (465,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=11, test_size=0.2
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (372, 14)
# (93, 14)
# (372,)
# (93,)
